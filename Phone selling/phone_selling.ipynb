# %% [markdown]
# ### import the modules and packages..
# Let's the import `matplotlib` and `seaborn` for data visualisation and  plotting graphs.

# %%
import matplotlib as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# import the data from csv file by using the pandas module.

# %%
# df=  pd.read_csv("top 120 best-selling mobile phones.csv").head(10)
df = pd.read_csv("D:\Data science\practice_project\Phone selling\\top 120 best-selling mobile phones.csv120 best-selling mobile phones.csv")
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\chour\AppData\Local\Temp\ipykernel_16016\2802177645.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("D:\Data science\practice_project\Phone selling\\top 120 best-selling mobile phones.csv120 best-selling mobile phones.csv")
# C:\Users\chour\AppData\Local\Temp\ipykernel_16016\2802177645.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("D:\Data science\practice_project\Phone selling\\top 120 best-selling mobile phones.csv120 best-selling mobile phones.csv")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # df=  pd.read_csv("top 120 best-selling mobile phones.csv").head(10)
# ...

# %% [markdown]
# get the unique phone manufacture companys

# %%
df.Manufacturer.unique()
# Out:
# array(['Nokia', 'Apple', 'Samsung', 'Motorola', 'Huawei', 'LG', 'Xiaomi',
#        'HTC', 'Sony Ericsson', 'Research in Motion (RIM)', 'Oppo', 'LeTV',
#        'Google', 'Palm'], dtype=object)

# %%
print("the shape of the dataset is ",df.shape)
# Out:
# the shape of the dataset is  (120, 7)

# %%
# information about datasets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   120 non-null    int64
#  1   Manufacturer           120 non-null    object
#  2   Model                  120 non-null    object
#  3   Form Factor            120 non-null    object
#  4   Smartphone?            120 non-null    bool
#  5   Year                   120 non-null    int64
#  6   Units Sold (million )  120 non-null    float64
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 5.9+ KB

# %% [markdown]
# check the null values in the datasets

# %%
df.isna().value_counts()
# Out:
# Rank   Manufacturer  Model  Form Factor  Smartphone?  Year   Units Sold (million )
# False  False         False  False        False        False  False                    120
# Name: count, dtype: int64

# %% [markdown]
# describe the data w.r.t to year

# %%
df["Year"].describe()
# Out:
# count     120.000000
# mean     2012.758333
# std         6.590030
# min      1996.000000
# 25%      2007.000000
# 50%      2013.000000
# 75%      2019.000000
# max      2024.000000
# Name: Year, dtype: float64

# %%
# sort the year--
data_year = np.sort(df.Year.unique())
data_year
# Out:
# array([1996, 1999, 2000, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024], dtype=int64)

# %%
df_man_counts = df["Model"].value_counts()
df_man_counts
# Out:
# Model
# 1100                          1
# 1110                          1
# Star/Tocco Lite (S5230)       1
# Shine                         1
# N95                           1
#                              ..
# iPhone 4                      1
# 6230(6233)                    1
# 3100(3120)                    1
# Galaxy S7 & Galaxy S7 edge    1
# Centro                        1
# Name: count, Length: 120, dtype: int64

# %%
df.describe().T
# Out:
#                        count         mean        std     min      25%  \
# Rank                   120.0    60.500000  34.785054     1.0    30.75
# Year                   120.0  2012.758333   6.590030  1996.0  2007.00
# Units Sold (million )  120.0    48.050000  58.044835     2.0    10.00
#
#                            50%      75%     max
# Rank                     60.50    90.25   120.0
# Year                   2013.00  2019.00  2024.0
# Units Sold (million )    22.05    60.00   250.0

# %%
plt.pyplot.figure(figsize=(15,8))
sns.set_theme()
plt.pyplot.title("top 10 best-selling mobile phones")
sns.scatterplot(y= "Manufacturer",
                x="Year",
                data = df,
                hue = 'Manufacturer');

# %%
# # top 10 selling phone
top_10 = df.head(20)
top_10
# Out:
#     Rank Manufacturer                                 Model  Form Factor  \
# 0      1        Nokia                                  1100          Bar
# 1      2        Nokia                                  1110          Bar
# 2      3        Apple                     iPhone 6 & 6 Plus  Touchscreen
# 3      4        Nokia                            105 Series          Bar
# 4      5        Apple                   iPhone 6S & 6S Plus  Touchscreen
# 5      6        Apple                             iPhone 5S  Touchscreen
# 6      7        Nokia                                  3210          Bar
# 7      8        Apple                     iPhone 7 & 7 Plus  Touchscreen
# 8      9        Apple           iPhone11, 11Pro & 11Pro Max  Touchscreen
# 9     10        Apple  iPhone XR, iPhone XS & iPhone XS Max  Touchscreen
# 10    11        Nokia                                  6600          Bar
# 11    12        Nokia                                  1200          Bar
# ...

# %%
man_counts = top_10["Manufacturer"].value_counts()
man_counts
# Out:
# Manufacturer
# Nokia       10
# Apple        8
# Samsung      1
# Motorola     1
# Name: count, dtype: int64

# %%
plt.pyplot.figure(figsize=(5,9))
plt.pyplot.title(top_10.Manufacturer.unique())
explode = (0.05, 0, 0, 0)
plt.pyplot.pie(man_counts , labels= man_counts.index,explode= explode, autopct= "%1.1f%%", shadow=True, startangle=90);
